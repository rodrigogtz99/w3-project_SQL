# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Actor Table

# %%
actor = pd.read_csv('actor.csv')

# %%
actors_todelete[['actor_id', 'first_name', 'last_name', 'last_update']] = actors_todelete['actor_id;first_name;last_name;last_update'].str.split(';', expand=True)

# %%
actors_todelete.drop(columns=['actor_id;first_name;last_name;last_update'], inplace=True)

# %%
actors_todelete['full_name'] = actors_todelete['first_name'] + ' ' + actors_todelete['last_name']

# %%
actors_movies['full_name'] = actors_movies['first_name'] + ' ' + actors_movies['last_name']

# %%
actors_todelete
# Out:
#     actor_id first_name     last_name    last_update            full_name
# 0          1   PENELOPE       GUINESS  15/2/06 04:34     PENELOPE GUINESS
# 1          2       NICK      WAHLBERG  15/2/06 04:34        NICK WAHLBERG
# 2          3         ED         CHASE  15/2/06 04:34             ED CHASE
# 3          4   JENNIFER         DAVIS  15/2/06 04:34       JENNIFER DAVIS
# 4          5     JOHNNY  LOLLOBRIGIDA  15/2/06 04:34  JOHNNY LOLLOBRIGIDA
# ..       ...        ...           ...            ...                  ...
# 195      196       BELA        WALKEN  15/2/06 04:34          BELA WALKEN
# 196      197      REESE          WEST  15/2/06 04:34           REESE WEST
# 197      198       MARY        KEITEL  15/2/06 04:34          MARY KEITEL
# 198      199      JULIA       FAWCETT  15/2/06 04:34        JULIA FAWCETT
# 199      200      THORA        TEMPLE  15/2/06 04:34         THORA TEMPLE
#
# [200 rows x 5 columns]

# %%
actors_movies = pd.merge(actors_movies, actors_todelete, on='full_name', how='left')

# %%
actors_movies.drop(columns=['first_name_x', 'last_name_x', 'first_name_y','last_name_y'], inplace=True)

# %%
actors_movies
# Out:
#                      title release_year category_id         full_name  \
# 0         ACADEMY DINOSAUR         2006           6  PENELOPE GUINESS
# 1     ANACONDA CONFESSIONS         2006           2  PENELOPE GUINESS
# 2              ANGELS LIFE         2006          13  PENELOPE GUINESS
# 3    BULWORTH COMMANDMENTS         2006          10  PENELOPE GUINESS
# 4            CHEAPER CLYDE         2006          14  PENELOPE GUINESS
# ..                     ...          ...         ...               ...
# 995      COMANCHEROS ENEMY         2006           3      GOLDIE BRODY
# 996        DAISY MENAGERIE         2006          14      GOLDIE BRODY
# 997        DESERT POSEIDON         2006          11      GOLDIE BRODY
# 998         EVERYONE CRAFT         2006           9      GOLDIE BRODY
# 999         EXORCIST STING         2006          15      GOLDIE BRODY
#
#     actor_id    last_update
# 0          1  15/2/06 04:34
# 1          1  15/2/06 04:34
# 2          1  15/2/06 04:34
# ...

# %%
desired_column_order = ['actor_id', 'full_name', 'title','category_id','release_year']

# %%
actors_movies = actors_movies[desired_column_order]

# %%
film = pd.read_csv('film.csv', delimiter=';')
actors_movies = pd.merge(actors_movies, film, on='title', how='left')

# %%
actors_movies.reset_index(drop=True, inplace=True)

# %%
actors_movies
# Out:
#     actor_id         full_name                  title category_id  \
# 0          1  PENELOPE GUINESS       ACADEMY DINOSAUR           6
# 1          1  PENELOPE GUINESS   ANACONDA CONFESSIONS           2
# 2          1  PENELOPE GUINESS            ANGELS LIFE          13
# 3          1  PENELOPE GUINESS  BULWORTH COMMANDMENTS          10
# 4          1  PENELOPE GUINESS          CHEAPER CLYDE          14
# ..       ...               ...                    ...         ...
# 995       39      GOLDIE BRODY      COMANCHEROS ENEMY           3
# 996       39      GOLDIE BRODY        DAISY MENAGERIE          14
# 997       39      GOLDIE BRODY        DESERT POSEIDON          11
# 998       39      GOLDIE BRODY         EVERYONE CRAFT           9
# 999       39      GOLDIE BRODY         EXORCIST STING          15
#
#     release_year_x  film_id  \
# 0             2006        1
# 1             2006       23
# 2             2006       25
# 3             2006      106
# ...

# %%
actors_movies.to_csv('actors_movies.csv', index=False)

# %%
actors_movies = actors_movies.drop_duplicates()

# %%
actors_movies.to_csv('actors_movies.csv', index=False)

# %% [markdown]
# # Inventory Table

# %%
inventory = pd.read_csv('inventory.csv',delimiter= ';')  
inventory
# Out:
#      inventory_id  film_id  store_id    last_update
# 0               1        1         1  15/2/06 05:09
# 1               2        1         1  15/2/06 05:09
# 2               3        1         1  15/2/06 05:09
# 3               4        1         1  15/2/06 05:09
# 4               5        1         2  15/2/06 05:09
# ..            ...      ...       ...            ...
# 995           996      222         2  15/2/06 05:09
# 996           997      222         2  15/2/06 05:09
# 997           998      222         2  15/2/06 05:09
# 998           999      223         2  15/2/06 05:09
# 999          1000      223         2  15/2/06 05:09
#
# [1000 rows x 4 columns]

# %% [markdown]
# # Film Table

# %%
film = pd.read_csv('film.csv',delimiter= ';')  
film
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...
