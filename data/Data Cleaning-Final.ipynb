# %%
import numpy as np
import pandas as pd

# %%
inventory = pd.read_csv('inventory.csv',delimiter= ';')  
actor = pd.read_csv('actor.csv',delimiter= ';')
old_HDD = pd.read_csv('old_HDD.csv',delimiter= ';') 
film = pd.read_csv('film.csv',delimiter= ';')  
category = pd.read_csv('category.csv',delimiter= ';') 
language = pd.read_csv('language.csv',delimiter= ';') 
rental = pd.read_csv('rental.csv',delimiter= ';')

# %% [markdown]
# # Actor Table

# %%
actor = pd.read_csv('actor.csv',delimiter= ';')
actor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    object
#  2   last_name    200 non-null    object
#  3   last_update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
actor.drop_duplicates(inplace=True)
actor.isnull().sum()
# Out:
# actor_id       0
# first_name     0
# last_name      0
# last_update    0
# dtype: int64

# %%
actor.duplicated().sum()
# Out:
# 0

# %%
actor.head()
# Out:
#    actor_id first_name     last_name    last_update
# 0         1   PENELOPE       GUINESS  15/2/06 04:34
# 1         2       NICK      WAHLBERG  15/2/06 04:34
# 2         3         ED         CHASE  15/2/06 04:34
# 3         4   JENNIFER         DAVIS  15/2/06 04:34
# 4         5     JOHNNY  LOLLOBRIGIDA  15/2/06 04:34

# %%
actor['full_name'] = actor['first_name'] + ' ' + actor['last_name']

# %%
actor.drop(columns = 'first_name', inplace = True)
actor.drop(columns = 'last_name', inplace = True)
actor.drop(columns = 'last_update', inplace= True)

# %%
actor
# Out:
#      actor_id            full_name
# 0           1     PENELOPE GUINESS
# 1           2        NICK WAHLBERG
# 2           3             ED CHASE
# 3           4       JENNIFER DAVIS
# 4           5  JOHNNY LOLLOBRIGIDA
# ..        ...                  ...
# 195       196          BELA WALKEN
# 196       197           REESE WEST
# 197       198          MARY KEITEL
# 198       199        JULIA FAWCETT
# 199       200         THORA TEMPLE
#
# [200 rows x 2 columns]

# %%
actor.to_csv('actor_clean.csv', index=False)

# %% [markdown]
# # Category Table

# %%
category
# Out:
#     category_id         name    last_update
# 0             1       Action  15/2/06 04:46
# 1             2    Animation  15/2/06 04:46
# 2             3     Children  15/2/06 04:46
# 3             4     Classics  15/2/06 04:46
# 4             5       Comedy  15/2/06 04:46
# 5             6  Documentary  15/2/06 04:46
# 6             7        Drama  15/2/06 04:46
# 7             8       Family  15/2/06 04:46
# 8             9      Foreign  15/2/06 04:46
# 9            10        Games  15/2/06 04:46
# 10           11       Horror  15/2/06 04:46
# 11           12        Music  15/2/06 04:46
# 12           13          New  15/2/06 04:46
# 13           14       Sci-Fi  15/2/06 04:46
# 14           15       Sports  15/2/06 04:46
# 15           16       Travel  15/2/06 04:46

# %%
new_row = {'category_id': '0', 'name': 'Unknown', 'last_update': '-'}
category = category.append(new_row, ignore_index=True)
category
# Out:
# /var/folders/9r/gs1g10c57dq76y5t067393s40000gn/T/ipykernel_18203/835959458.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   category = category.append(new_row, ignore_index=True)
#    category_id         name    last_update
# 0            1       Action  15/2/06 04:46
# 1            2    Animation  15/2/06 04:46
# 2            3     Children  15/2/06 04:46
# 3            4     Classics  15/2/06 04:46
# 4            5       Comedy  15/2/06 04:46
# 5            6  Documentary  15/2/06 04:46
# 6            7        Drama  15/2/06 04:46
# 7            8       Family  15/2/06 04:46
# 8            9      Foreign  15/2/06 04:46
# 9           10        Games  15/2/06 04:46
# 10          11       Horror  15/2/06 04:46
# 11          12        Music  15/2/06 04:46
# 12          13          New  15/2/06 04:46
# 13          14       Sci-Fi  15/2/06 04:46
# 14          15       Sports  15/2/06 04:46
# 15          16       Travel  15/2/06 04:46
# 16           0      Unknown              -

# %%
category.drop(columns='last_update',inplace= True)
category
# Out:
#    category_id         name
# 0            1       Action
# 1            2    Animation
# 2            3     Children
# 3            4     Classics
# 4            5       Comedy
# 5            6  Documentary
# 6            7        Drama
# 7            8       Family
# 8            9      Foreign
# 9           10        Games
# 10          11       Horror
# 11          12        Music
# 12          13          New
# 13          14       Sci-Fi
# 14          15       Sports
# 15          16       Travel
# 16           0      Unknown

# %% [markdown]
# # old_HDD Table

# %%
old_HDD = pd.read_csv('old_HDD.csv',delimiter= ';')

# %%
old_HDD
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
old_HDD.duplicated().sum()
# Out:
# 0

# %%
old_HDD.isnull().sum()
# Out:
# first_name      0
# last_name       0
# title           0
# release_year    0
# category_id     0
# dtype: int64

# %%
old_HDD = pd.merge(old_HDD, film, on='title', how='right')
old_HDD.isnull().sum()
# Out:
# first_name               386
# last_name                386
# title                      0
# release_year_x           386
# category_id              386
# film_id                    0
# description                0
# release_year_y             0
# language_id                0
# original_language_id    1386
# rental_duration            0
# rental_rate                0
# length                     0
# replacement_cost           0
# rating                     0
# special_features           0
# last_update                0
# dtype: int64

# %%
old_HDD.drop(columns='original_language_id',inplace= True)

# %%
old_HDD.drop(columns=['first_name', 'last_name', 'release_year_x'], inplace=True)

# %%
old_HDD.duplicated().sum()
# Out:
# 386

# %%
old_HDD.drop_duplicates(inplace=True)

# %%
old_HDD.isnull().sum()
# Out:
# title                 0
# category_id         386
# film_id               0
# description           0
# release_year_y        0
# language_id           0
# rental_duration       0
# rental_rate           0
# length                0
# replacement_cost      0
# rating                0
# special_features      0
# last_update           0
# dtype: int64

# %%
old_HDD
# Out:
#                   title  category_id  film_id  \
# 0      ACADEMY DINOSAUR          6.0        1
# 4        ACE GOLDFINGER         11.0        2
# 5      ADAPTATION HOLES          6.0        3
# 8      AFFAIR PREJUDICE          NaN        4
# 9           AFRICAN EGG          NaN        5
# ...                 ...          ...      ...
# 1379     YOUNG LANGUAGE          6.0      996
# 1381         YOUTH KICK         12.0      997
# 1383       ZHIVAGO CORE         11.0      998
# 1384  ZOOLANDER FICTION          NaN      999
# 1385          ZORRO ARK          NaN     1000
#
#                                             description  release_year_y  \
# 0     A Epic Drama of a Feminist And a Mad Scientist...            2006
# 4     A Astounding Epistle of a Database Administrat...            2006
# 5     A Astounding Reflection of a Lumberjack And a ...            2006
# 8     A Fanciful Documentary of a Frisbee And a Lumb...            2006
# 9     A Fast-Paced Documentary of a Pastry Chef And ...            2006
# ...                                                 ...             ...
# 1379  A Unbelieveable Yarn of a Boat And a Database ...            2006
# 1381  A Touching Drama of a Teacher And a Cat who mu...            2006
# 1383  A Fateful Yarn of a Composer And a Man who mus...            2006
# 1384  A Fateful Reflection of a Waitress And a Boat ...            2006
# 1385  A Intrepid Panorama of a Mad Scientist And a B...            2006
#
#       language_id  rental_duration  rental_rate  length  replacement_cost  \
# 0               1                6         0.99      86             20.99
# 4               1                3         4.99      48             12.99
# 5               1                7         2.99      50             18.99
# 8               1                5         2.99     117             26.99
# 9               1                6         2.99     130             22.99
# ...           ...              ...          ...     ...               ...
# 1379            1                6         0.99     183              9.99
# 1381            1                4         0.99     179             14.99
# 1383            1                6         0.99     105             10.99
# 1384            1                5         2.99     101             28.99
# 1385            1                3         4.99      50             18.99
#
#      rating                         special_features    last_update
# 0        PG         Deleted Scenes,Behind the Scenes  15/2/06 05:03
# 4         G                  Trailers,Deleted Scenes  15/2/06 05:03
# 5     NC-17                  Trailers,Deleted Scenes  15/2/06 05:03
# 8         G           Commentaries,Behind the Scenes  15/2/06 05:03
# 9         G                           Deleted Scenes  15/2/06 05:03
# ...     ...                                      ...            ...
# 1379      G               Trailers,Behind the Scenes  15/2/06 05:03
# 1381  NC-17               Trailers,Behind the Scenes  15/2/06 05:03
# 1383  NC-17                           Deleted Scenes  15/2/06 05:03
# 1384      R                  Trailers,Deleted Scenes  15/2/06 05:03
# 1385  NC-17  Trailers,Commentaries,Behind the Scenes  15/2/06 05:03
#
# [1000 rows x 13 columns]

# %%
old_HDD.fillna(0, inplace=True)
old_HDD.isnull().sum()
# Out:
# title               0
# category_id         0
# film_id             0
# description         0
# release_year_y      0
# language_id         0
# rental_duration     0
# rental_rate         0
# length              0
# replacement_cost    0
# rating              0
# special_features    0
# last_update         0
# dtype: int64

# %%
old_HDD.head(3)
# Out:
#               title  category_id  film_id  \
# 0  ACADEMY DINOSAUR          6.0        1
# 4    ACE GOLDFINGER         11.0        2
# 5  ADAPTATION HOLES          6.0        3
#
#                                          description  release_year_y  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...            2006
# 4  A Astounding Epistle of a Database Administrat...            2006
# 5  A Astounding Reflection of a Lumberjack And a ...            2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                6         0.99      86             20.99     PG
# 4            1                3         4.99      48             12.99      G
# 5            1                7         2.99      50             18.99  NC-17
#
#                    special_features    last_update
# 0  Deleted Scenes,Behind the Scenes  15/2/06 05:03
# 4           Trailers,Deleted Scenes  15/2/06 05:03
# 5           Trailers,Deleted Scenes  15/2/06 05:03

# %%
old_HDD.drop(columns='last_update', inplace=True)

# %%
old_HDD['category_id'] = old_HDD['category_id'].astype(int)

# %%
desired_order = ['film_id', 'title','category_id','release_year_y','description','language_id','rental_duration','rental_rate','length','rating','special_features','replacement_cost']
old_HDD = old_HDD.reindex(columns=desired_order)

# %%
film = old_HDD

# %%
film.rename(columns={'release_year_y': 'release_year'}, inplace=True)
film
# Out:
#       film_id              title  category_id  release_year  \
# 0           1   ACADEMY DINOSAUR            6          2006
# 4           2     ACE GOLDFINGER           11          2006
# 5           3   ADAPTATION HOLES            6          2006
# 8           4   AFFAIR PREJUDICE            0          2006
# 9           5        AFRICAN EGG            0          2006
# ...       ...                ...          ...           ...
# 1379      996     YOUNG LANGUAGE            6          2006
# 1381      997         YOUTH KICK           12          2006
# 1383      998       ZHIVAGO CORE           11          2006
# 1384      999  ZOOLANDER FICTION            0          2006
# 1385     1000          ZORRO ARK            0          2006
#
#                                             description  language_id  \
# 0     A Epic Drama of a Feminist And a Mad Scientist...            1
# 4     A Astounding Epistle of a Database Administrat...            1
# 5     A Astounding Reflection of a Lumberjack And a ...            1
# 8     A Fanciful Documentary of a Frisbee And a Lumb...            1
# 9     A Fast-Paced Documentary of a Pastry Chef And ...            1
# ...                                                 ...          ...
# 1379  A Unbelieveable Yarn of a Boat And a Database ...            1
# 1381  A Touching Drama of a Teacher And a Cat who mu...            1
# 1383  A Fateful Yarn of a Composer And a Man who mus...            1
# 1384  A Fateful Reflection of a Waitress And a Boat ...            1
# 1385  A Intrepid Panorama of a Mad Scientist And a B...            1
#
#       rental_duration  rental_rate  length rating  \
# 0                   6         0.99      86     PG
# 4                   3         4.99      48      G
# 5                   7         2.99      50  NC-17
# 8                   5         2.99     117      G
# 9                   6         2.99     130      G
# ...               ...          ...     ...    ...
# 1379                6         0.99     183      G
# 1381                4         0.99     179  NC-17
# 1383                6         0.99     105  NC-17
# 1384                5         2.99     101      R
# 1385                3         4.99      50  NC-17
#
#                              special_features  replacement_cost
# 0            Deleted Scenes,Behind the Scenes             20.99
# 4                     Trailers,Deleted Scenes             12.99
# 5                     Trailers,Deleted Scenes             18.99
# 8              Commentaries,Behind the Scenes             26.99
# 9                              Deleted Scenes             22.99
# ...                                       ...               ...
# 1379               Trailers,Behind the Scenes              9.99
# 1381               Trailers,Behind the Scenes             14.99
# 1383                           Deleted Scenes             10.99
# 1384                  Trailers,Deleted Scenes             28.99
# 1385  Trailers,Commentaries,Behind the Scenes             18.99
#
# [1000 rows x 12 columns]

# %%
old_HDD2 = pd.read_csv('old_HDD2.csv',delimiter= ';')

# %%
old_HDD2
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
old_HDD2['full_name'] = old_HDD2['first_name'] + ' ' + old_HDD2['last_name']

# %%
old_HDD2.drop(columns='first_name', inplace=True)
old_HDD2.drop(columns='last_name', inplace=True)

# %%
old_HDD2
# Out:
#                      title  release_year  category_id         full_name
# 0         ACADEMY DINOSAUR          2006            6  PENELOPE GUINESS
# 1     ANACONDA CONFESSIONS          2006            2  PENELOPE GUINESS
# 2              ANGELS LIFE          2006           13  PENELOPE GUINESS
# 3    BULWORTH COMMANDMENTS          2006           10  PENELOPE GUINESS
# 4            CHEAPER CLYDE          2006           14  PENELOPE GUINESS
# ..                     ...           ...          ...               ...
# 995      COMANCHEROS ENEMY          2006            3      GOLDIE BRODY
# 996        DAISY MENAGERIE          2006           14      GOLDIE BRODY
# 997        DESERT POSEIDON          2006           11      GOLDIE BRODY
# 998         EVERYONE CRAFT          2006            9      GOLDIE BRODY
# 999         EXORCIST STING          2006           15      GOLDIE BRODY
#
# [1000 rows x 4 columns]

# %%
old_HDD2 = pd.merge(old_HDD2, actor, on='full_name', how='inner')
old_HDD2 = pd.merge(old_HDD2, film, on='title', how='right')

# %%
old_HDD2.drop(columns=['release_year_x', 'title','full_name','category_id_x'], inplace=True)

# %%
old_HDD2.drop(columns=['category_id_y', 'description','language_id','rental_duration','rental_rate','length','rating','special_features','replacement_cost'], inplace=True)

# %%
old_HDD2 = old_HDD2.dropna()
old_HDD2 = old_HDD2.drop_duplicates()

# %%
old_HDD2['actor_id'] = old_HDD2['actor_id'].astype(int)

# %%
old_HDD2 = old_HDD2.drop(columns=['release_year_y'])

# %%
old_HDD2
# Out:
#       actor_id  film_id
# 0            1        1
# 1           10        1
# 2           20        1
# 3           30        1
# 4           19        2
# ...        ...      ...
# 1379         3      996
# 1380        27      996
# 1381        23      997
# 1382        37      997
# 1383        13      998
#
# [1000 rows x 2 columns]

# %%
actor_movie = old_HDD2
actor_movie
# Out:
#       actor_id  film_id
# 0            1        1
# 1           10        1
# 2           20        1
# 3           30        1
# 4           19        2
# ...        ...      ...
# 1379         3      996
# 1380        27      996
# 1381        23      997
# 1382        37      997
# 1383        13      998
#
# [1000 rows x 2 columns]

# %%
actor_movie.to_csv('actor_movie_clean.csv', index=False)

# %% [markdown]
# # Inventory Table

# %%
inventory
# Out:
#      inventory_id  film_id  store_id    last_update
# 0               1        1         1  15/2/06 05:09
# 1               2        1         1  15/2/06 05:09
# 2               3        1         1  15/2/06 05:09
# 3               4        1         1  15/2/06 05:09
# 4               5        1         2  15/2/06 05:09
# ..            ...      ...       ...            ...
# 995           996      222         2  15/2/06 05:09
# 996           997      222         2  15/2/06 05:09
# 997           998      222         2  15/2/06 05:09
# 998           999      223         2  15/2/06 05:09
# 999          1000      223         2  15/2/06 05:09
#
# [1000 rows x 4 columns]

# %%
inventory.isnull().sum()
# Out:
# inventory_id    0
# film_id         0
# store_id        0
# last_update     0
# dtype: int64

# %%
inventory.duplicated().sum()
# Out:
# 0

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
#  3   last_update   1000 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
inventory.drop(columns='last_update', inplace=True)

# %%
inventory
# Out:
#      inventory_id  film_id  store_id
# 0               1        1         1
# 1               2        1         1
# 2               3        1         1
# 3               4        1         1
# 4               5        1         2
# ..            ...      ...       ...
# 995           996      222         2
# 996           997      222         2
# 997           998      222         2
# 998           999      223         2
# 999          1000      223         2
#
# [1000 rows x 3 columns]

# %% [markdown]
# # Language Table

# %%
language = pd.read_csv('language.csv',delimiter= ';') 
language
# Out:
#    language_id      name    last_update
# 0            1   English  15/2/06 05:02
# 1            2   Italian  15/2/06 05:02
# 2            3  Japanese  15/2/06 05:02
# 3            4  Mandarin  15/2/06 05:02
# 4            5    French  15/2/06 05:02
# 5            6    German  15/2/06 05:02

# %%
language.isnull().sum()
# Out:
# language_id    0
# name           0
# last_update    0
# dtype: int64

# %%
language.duplicated().sum()
# Out:
# 0

# %%
language.drop(columns='last_update', inplace=True)

# %%
language
# Out:
#    language_id      name
# 0            1   English
# 1            2   Italian
# 2            3  Japanese
# 3            4  Mandarin
# 4            5    French
# 5            6    German

# %% [markdown]
# # Rental Table

# %%
rental
# Out:
#      rental_id    rental_date  inventory_id  customer_id    return_date  \
# 0            1  24/5/05 22:53           367          130  26/5/05 22:04
# 1            2  24/5/05 22:54          1525          459  28/5/05 19:40
# 2            3  24/5/05 23:03          1711          408   1/6/05 22:12
# 3            4  24/5/05 23:04          2452          333   3/6/05 01:43
# 4            5  24/5/05 23:05          2079          222   2/6/05 04:33
# ..         ...            ...           ...          ...            ...
# 995        997  31/5/05 00:08          4243          216   2/6/05 00:17
# 996        998  31/5/05 00:16          3395          389   1/6/05 22:41
# 997        999  31/5/05 00:25          4433          413   3/6/05 06:05
# 998       1000  31/5/05 00:25          1774          332   8/6/05 19:42
# 999       1001  31/5/05 00:46          1498           64   6/6/05 06:14
#
#      staff_id    last_update
# 0           1  15/2/06 21:30
# 1           1  15/2/06 21:30
# 2           1  15/2/06 21:30
# 3           2  15/2/06 21:30
# 4           1  15/2/06 21:30
# ..        ...            ...
# 995         2  15/2/06 21:30
# 996         1  15/2/06 21:30
# 997         2  15/2/06 21:30
# 998         2  15/2/06 21:30
# 999         2  15/2/06 21:30
#
# [1000 rows x 7 columns]

# %%
rental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     1000 non-null   int64
#  1   rental_date   1000 non-null   object
#  2   inventory_id  1000 non-null   int64
#  3   customer_id   1000 non-null   int64
#  4   return_date   1000 non-null   object
#  5   staff_id      1000 non-null   int64
#  6   last_update   1000 non-null   object
# dtypes: int64(4), object(3)
# memory usage: 54.8+ KB

# %%
rental.isnull().sum()
# Out:
# rental_id       0
# rental_date     0
# inventory_id    0
# customer_id     0
# return_date     0
# staff_id        0
# last_update     0
# dtype: int64

# %%
rental.duplicated().sum()
# Out:
# 0

# %%
rental.head()
# Out:
#    rental_id    rental_date  inventory_id  customer_id    return_date  \
# 0          1  24/5/05 22:53           367          130  26/5/05 22:04
# 1          2  24/5/05 22:54          1525          459  28/5/05 19:40
# 2          3  24/5/05 23:03          1711          408   1/6/05 22:12
# 3          4  24/5/05 23:04          2452          333   3/6/05 01:43
# 4          5  24/5/05 23:05          2079          222   2/6/05 04:33
#
#    staff_id    last_update
# 0         1  15/2/06 21:30
# 1         1  15/2/06 21:30
# 2         1  15/2/06 21:30
# 3         2  15/2/06 21:30
# 4         1  15/2/06 21:30

# %%
rental.drop(columns='last_update', inplace=True)

# %%
len(rental)
# Out:
# 1000

# %%
rental.tail()
# Out:
#      rental_id    rental_date  inventory_id  customer_id   return_date  \
# 995        997  31/5/05 00:08          4243          216  2/6/05 00:17
# 996        998  31/5/05 00:16          3395          389  1/6/05 22:41
# 997        999  31/5/05 00:25          4433          413  3/6/05 06:05
# 998       1000  31/5/05 00:25          1774          332  8/6/05 19:42
# 999       1001  31/5/05 00:46          1498           64  6/6/05 06:14
#
#      staff_id
# 995         2
# 996         1
# 997         2
# 998         2
# 999         2

# %%
rental['rental_date'] = pd.to_datetime(rental['rental_date'], format='%d/%m/%y %H:%M')

# %%
rental['return_date'] = pd.to_datetime(rental['return_date'], format='%d/%m/%y %H:%M')

# %%
rental
# Out:
#      rental_id         rental_date  inventory_id  customer_id  \
# 0            1 2005-05-24 22:53:00           367          130
# 1            2 2005-05-24 22:54:00          1525          459
# 2            3 2005-05-24 23:03:00          1711          408
# 3            4 2005-05-24 23:04:00          2452          333
# 4            5 2005-05-24 23:05:00          2079          222
# ..         ...                 ...           ...          ...
# 995        997 2005-05-31 00:08:00          4243          216
# 996        998 2005-05-31 00:16:00          3395          389
# 997        999 2005-05-31 00:25:00          4433          413
# 998       1000 2005-05-31 00:25:00          1774          332
# 999       1001 2005-05-31 00:46:00          1498           64
#
#             return_date  staff_id
# 0   2005-05-26 22:04:00         1
# 1   2005-05-28 19:40:00         1
# 2   2005-06-01 22:12:00         1
# 3   2005-06-03 01:43:00         2
#          5, 363, 454, 276, 483, 420, 576, 435, 563, 146,  50, 149, 124,
#        352,  72,  27, 562, 553, 593,  26, 402, 171, 235, 225, 474, 441,
#        573, 217,  79, 380, 517, 530, 122, 406, 358, 328,   8,  99,  52,
#        326, 339, 477,  62, 128, 349, 192, 156, 561, 486, 366, 115, 385,
#        550, 137, 141,  66, 367, 210, 440, 520, 581, 279, 262,  11,  12,
#        123, 513, 216, 389])

# %%
customer = pd.DataFrame(customer1, columns=['customer_id'])

# %%
customer = customer.sort_values(by='customer_id', ascending=True)

# %%
customer = customer.reset_index(drop=True)

# %%
import random
import string

# Function to generate a random name
def generate_random_name():
    letters = string.ascii_lowercase
    return ''.join(random.choice(letters).capitalize() for i in range(5))

names_list = [generate_random_name() for _ in range(485)]
print(names_list)
customer['Names']= names_list
# Out:
# ['WYOJM', 'LDEAP', 'NMLGI', 'IYNBF', 'NXVVT', 'KOCCN', 'KTJHS', 'FHWMS', 'SUJNA', 'EAQPB', 'BKUUD', 'MHHYW', 'YDASV', 'UQQZG', 'OFURR', 'OXQJD', 'JQSYN', 'QGNTC', 'AOQYR', 'TQCGB', 'NCINU', 'RRHJU', 'QJGDD', 'NWWZA', 'JZOWW', 'ESCYQ', 'WSRTS', 'ZYRMU', 'BLTOP', 'PJTHN', 'CSJVS', 'WPVJX', 'MTIQX', 'YIBFC', 'ZSRNG', 'SHYXZ', 'DCYLO', 'HZDDP', 'OEHQH', 'PDLGN', 'QLLGT', 'HVNCW', 'FLCTY', 'VVPLA', 'GQNDF', 'QPDTO', 'UUYVK', 'QOIFD', 'BKBFQ', 'ZBEEK', 'ZISLP', 'NTDDM', 'GQNQG', 'JOCXH', 'VPOQD', 'ITKPG', 'YGSRC', 'VDAGE', 'BEBPN', 'KAVUG', 'NXTZH', 'AMNDM', 'HHRXR', 'LBGKH', 'UQYQS', 'BVFEI', 'HRUZE', 'ZUPZP', 'PGTIH', 'SHKIC', 'FQGOL', 'FGLDI', 'NYYZY', 'TQPYB', 'IYVKX', 'HKLIX', 'QDRWL', 'XSCBT', 'JOTNH', 'RRLCT', 'DKDAM', 'JXZZV', 'EOZPN', 'XFWBK', 'WTQQM', 'ZQNLJ', 'HIQIL', 'JGAMW', 'MXRCK', 'MTFHK', 'XYGVD', 'UEPPD', 'WMNYG', 'EIDVS', 'AVNDZ', 'HABOI', 'HMVRJ', 'AUMAO', 'IGSYI', 'WVQLJ', 'WNOWP', 'JBPBG', 'ZNDWO', 'IPFNK', 'KSTPT', 'HGKZL', 'TZSWE', 'VSNJB', 'VFLIQ', 'YYIVK', 'HMVAH', 'WKKLF', 'NGSLW', 'IMNUE', 'IJLYN', 'GVXIE', 'IISYW', 'TPESY', 'XIOIX', 'WGVLD', 'BYUZY', 'LYMBJ', 'RPAWC', 'JTDDQ', 'CJUYS', 'NXCSP', 'SKCXX', 'IONOM', 'LEPOC', 'JLJKY', 'VZHKC', 'XVQR
H', 'QXVGH', 'EMALU', 'GJWRP', 'ZFUIP', 'CTIBV', 'PNMFC', 'VWVER', 'NHIRL', 'VDBVB', 'CRDET', 'AWELR', 'UFJFE', 'JPFXM', 'RKGOK', 'VFSIZ', 'YGBPY', 'YLDTJ', 'XYPVL', 'HRCPI', 'PKKKX', 'ARUWW', 'KVFVX', 'ZCYNM', 'YGUNA', 'OTGGO', 'GMJFO', 'JMRYF', 'KQUHS', 'VQLQF', 'MFWNW', 'FBOAS', 'PPYHC', 'WDNTO', 'THQAH', 'IUGTD', 'CRVMZ', 'QGMAX', 'DPQJJ', 'EPSQU', 'ONZQG', 'GSPUD', 'GIFRO', 'CNWYK', 'EROCC', 'DFWRD', 'HFQOP', 'WIRVS', 'JTDMQ', 'SEMEA', 'XLAXC', 'WVQYD', 'AXUNH', 'EQZDU', 'JKVXJ', 'KJVKZ', 'JIORF', 'AMAIS', 'HVIOY', 'KNLMK', 'GYPWI', 'VLXXG', 'VZPHT', 'NYMNB', 'QLDJY', 'PEATB', 'FJCTQ', 'EQLQQ', 'AKEIO', 'RHGAK', 'VBOXD', 'UTFYT', 'QUZKI', 'GLGYB', 'ZWYEX', 'DMWFT', 'DRCUO', 'HLIKY', 'ZHIRF', 'KXGYJ', 'MWPYR', 'LJEAZ', 'IZVZF', 'NXXPA', 'BYLCK', 'BKGMW', 'KXQLY', 'GVGEZ', 'BGDKJ', 'BXSSI', 'OYJXP', 'BTSVG', 'XOOPO', 'XWYRU', 'UJPWL', 'GENHM', 'QISNN', 'LNTZJ', 'WEBLI', 'HFKNP', 'EZNDC', 'YIGST', 'FGYRZ', 'XNXAC', 'JCTSL', 'GAYHU', 'MYBAZ', 'HDKYG', 'PCFAK', 'VWVBS', 'RUYNX', 'NRCKH', 'FNUSI', 'EMFWR', 'MUTNO', 'EPDSZ', 'MGIMS', 'OVLAR', 'VYGJO', 'ARGBY', 'GGIKY', 'GNCHD', 'CEJYF', 'JPRRZ', 'IKWNT', 'SPUHI', 'UCFXQ', 'WNKIB', 'QR ...

# %%
customer.rename(columns={'Names': 'names'}, inplace=True)

# %%
customer
# Out:
#      customer_id  names
# 0              1  WYOJM
# 1              2  LDEAP
# 2              3  NMLGI
# 3              5  IYNBF
# 4              6  NXVVT
# ..           ...    ...
# 480          593  JSFWC
# 481          594  DDAZN
# 482          595  MWVBB
# 483          596  ALOIA
# 484          597  WOCVS
#
# [485 rows x 2 columns]

# %%
import random

def generate_random_phone_number():
    area_code = random.randint(100, 999)
    first_part = random.randint(100, 999)
    second_part = random.randint(1000, 9999)
    return f"({area_code}) {first_part}-{second_part}"

# Generate a list of 485 phone numbers
phone_numbers = [generate_random_phone_number() for _ in range(485)]

# Display the list containing 485 phone numbers
print(phone_numbers)
# Out:
662-1086', '(860) 906-1468', '(846) 615-4823', '(837) 907-1134', '(554) 166-8314', '(137) 415-5651', '(579) 561-1719', '(338) 831-8930', '(893) 128-2426', '(234) 496-5409', '(204) 672-3806', '(669) 973-7155', '(301) 114-8449', '(461) 270-9623', '(153) 235-2882', '(119) 124-8945', '(557) 259-4218', '(298) 425-1086', '(620) 158-4494', '(191) 729-1207', '(529) 165-8302', '(920) 774-9808', '(621) 777-5254', '(193) 945-8819', '(521) 333-6109', '(310) 983-5173', '(915) 249-6729', '(102) 964-9193', '(232) 642-2061', '(619) 955-9597', '(437) 116-5945', '(249) 592-6587', '(303) 528-6754', '(548) 726-1463', '(204) 898-2532', '(685) 856-1009', '(167) 353-5442', '(166) 116-8299', '(164) 359-3425', '(712) 726-7226', '(884) 635-5337', '(268) 820-9375', '(588) 484-5501', '(419) 163-6289', '(677) 244-9544', '(779) 108-1580', '(754) 219-1628', '(939) 756-2993', '(503) 360-9296', '(806) 850-9154', '(427) 135-1617', '(909) 842-4277', '(424) 143-8394', '(111) 304-6235', '(358) 208-4866', '(989) 307-7953', '(805) 795-9139', '(801) 670-7934', '(425) 271-6274', '(239) 872-8356', '(635) 167-9575', '(920) 383-8606', '(481) 281-2313', '(2 ...

# %%
customer['phone_number']= phone_numbers

# %%
customer
# Out:
#      customer_id  names    phone_number
# 0              1  WYOJM  (893) 435-9194
# 1              2  LDEAP  (638) 252-8481
# 2              3  NMLGI  (410) 621-1276
# 3              5  IYNBF  (266) 262-5926
# 4              6  NXVVT  (136) 342-3708
# ..           ...    ...             ...
# 480          593  JSFWC  (744) 168-1048
# 481          594  DDAZN  (288) 798-9085
# 482          595  MWVBB  (776) 564-2771
# 483          596  ALOIA  (757) 494-6937
# 484          597  WOCVS  (715) 438-9274
#
# [485 rows x 3 columns]

# %% [markdown]
# # New table: Staff

# %%
staff = rental['staff_id'].unique()

# %%
staff = pd.DataFrame(staff, columns=['staff_id'])

# %%
staff
# Out:
#    staff_id
# 0         1
# 1         2

# %%
staff['names']= ['Lorraine Sanchez', 'Christopher Perez']

# %%
staff
# Out:
#    staff_id              names
# 0         1   Lorraine Sanchez
# 1         2  Christopher Perez

# %%
staff
# Out:
#    staff_id              names
# 0         1   Lorraine Sanchez
# 1         2  Christopher Perez

# %%
inventory.to_csv('inventory_clean.csv', index=False)
actor.to_csv('actor_clean.csv', index=False)
film.to_csv('film_clean.csv', index=False)
category.to_csv('category_clean.csv', index=False)
language.to_csv('language_clean.csv', index=False)
customer.to_csv('customer_clean.csv',index= False)
staff.to_csv('staff_clean.csv',index= False)

# %%
rental_inventory_ids = set(rental['inventory_id'])
inventory_inventory_ids = set(inventory['inventory_id'])

# Identify the inventory_id values in rental that are not in inventory
invalid_inventory_ids = rental_inventory_ids - inventory_inventory_ids

# Delete rows with invalid inventory_id values from the rental DataFrame
rental = rental[~rental['inventory_id'].isin(invalid_inventory_ids)]

# %%
rental.to_csv('rental_clean.csv', index=False)
